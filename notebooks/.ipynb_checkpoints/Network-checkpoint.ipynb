# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed, Bidirectional
from sklearn.model_selection import train_test_split
import pickle
import numpy as np
from music21 import *

# %%
# load the datasets and then split in to train/test data sets
# this all has to be done at the same time to ensure that the durations/pitches are from the same samples
with open("pickles/duration_X_train.pickle", 'rb') as duration_x, open('pickles/duration_Y_train.pickle', 'rb') as duration_y,\
    open("pickles/pitch_X_train.pickle", 'rb') as pitch_x, open('pickles/pitch_Y_train.pickle', 'rb') as pitch_y:
    duration_X_train, duration_X_test, duration_Y_train, duration_Y_test,\
    pitch_X_train, pitch_X_test, pitch_Y_train, pitch_Y_test\
    = train_test_split(pickle.load(duration_x), pickle.load(duration_y),\
                       pickle.load(pitch_x), pickle.load(pitch_y), train_size=0.95)

# %%
# retrieve the pitches and durations that were used to build the data set
# these will be used to convert the output one-hot vectors back to actual pitch/duration values
with open('pickles/durations.pickle', 'rb') as d, open('pickles/pitches.pickle', 'rb') as p:
    durations = pickle.load(d)
    pitches = pickle.load(p)

# %%
num_samples = duration_X_train.shape[0]  # applies to both pitch and duration data sets
timesteps = duration_X_train.shape[1]  # applies to both pitch and duration data sets
duration_num_features = duration_X_train.shape[2]
pitch_num_features = pitch_X_train.shape[2]

# %%
# single layer Unidirectional or Bidirectional LSTM; will easily allow us to test various configurations
def getModel(t, num_features, bidirectional=True):
    model = Sequential()
    # only dif. betwn. bi. LSTM and uni. LSTM is the presence/absence of Bidirectional wrapper
    # hidden layer 1; 20  units; input (# timesteps, # features); return a sequence of each time step's outputs
    if bidirectional:
        model.add(Bidirectional(LSTM(20, input_shape=(t, num_features), return_sequences=True)))
    else:
        model.add(LSTM(20, input_shape=(t, num_features), return_sequences=True))
        
    # TimeDistributed is a wrapper allowing one output per time step; 
    # ...requires hidden layer to have return_sequences == True
    model.add(TimeDistributed(Dense(num_features, activation='softmax')))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'categorical_crossentropy'])
    return model

# %%
# train LSTM
def trainModel(model, X, Y, epochs=10):
    # generate new random sequence
    # fit model for one epoch on this sequence
    model.fit(X, Y, epochs=epochs, verbose=1, validation_split=0.2)

# %%
duration_bidirectional = getModel(timesteps, duration_num_features, bidirectional=True)
trainModel(duration_bidirectional, duration_X_train, duration_Y_train)
# Out:
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 8s 28ms/sample - loss: 0.2080 - accuracy: 0.9492 - categorical_crossentropy: 1.2971 - val_loss: 0.1975 - val_accuracy: 0.9503 - val_categorical_crossentropy: 1.1903
# Epoch 2/10
# 294/294 [==============================] - 2s 6ms/sample - loss: 0.1935 - accuracy: 0.9492 - categorical_crossentropy: 1.1569 - val_loss: 0.1814 - val_accuracy: 0.9503 - val_categorical_crossentropy: 1.0394
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1747 - accuracy: 0.9492 - categorical_crossentropy: 0.9855 - val_loss: 0.1597 - val_accuracy: 0.9503 - val_categorical_crossentropy: 0.8500
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1522 - accuracy: 0.9569 - categorical_crossentropy: 0.7931 - val_loss: 0.1432 - val_accuracy: 0.9643 - val_categorical_crossentropy: 0.7027
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1409 - accuracy: 0.9615 - categorical_crossentropy: 0.6821 - val_loss: 0.1362 - val_accuracy: 0.9668 - val_categorical_crossentropy: 0.6411
# Epoch 6/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1336 - accuracy: 0.9668 - categorical_crossentropy: 0.6286 - val_loss: 0.1319 - val_accuracy: 0.9677 - val_categorical_crossentropy: 0.6107
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1292 - accuracy: 0.9678 - categorical_crossentropy: 0.5929 - val_loss: 0.1282 - val_accuracy: 0.9691 - val_categorical_crossentropy: 0.5786
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1256 - accuracy: 0.9688 - categorical_crossentropy: 0.5628 - val_loss: 0.1252 - val_accuracy: 0.9694 - val_categorical_crossentropy: 0.5568
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1225 - accuracy: 0.9692 - categorical_crossentropy: 0.5401 - val_loss: 0.1222 - val_accuracy: 0.9701 - val_categorical_crossentropy: 0.5347
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1197 - accuracy: 0.9699 - categorical_crossentropy: 0.5185 - val_loss: 0.1196 - val_accuracy: 0.9712 - val_categorical_crossentropy: 0.5151
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1170 - accuracy: 0.9708 - categorical_crossentropy: 0.4986 - val_loss: 0.1172 - val_accuracy: 0.9719 - val_categorical_crossentropy: 0.4971
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1144 - accuracy: 0.9722 - categorical_crossentropy: 0.4803 - val_loss: 0.1146 - val_accuracy: 0.9732 - val_categorical_crossentropy: 0.4802
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1117 - accuracy: 0.9738 - categorical_crossentropy: 0.4622 - val_loss: 0.1120 - val_accuracy: 0.9744 - val_categorical_crossentropy: 0.4623
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.1090 - accuracy: 0.9751 - categorical_crossentropy: 0.4433 - val_loss: 0.1093 - val_accuracy: 0.9761 - val_categorical_crossentropy: 0.4433
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.1061 - accuracy: 0.9767 - categorical_crossentropy: 0.4234 - val_loss: 0.1064 - val_accuracy: 0.9779 - val_categorical_crossentropy: 0.4246
# Epoch 6/10
# 294/294 [==============================] - 3s 10ms/sample - loss: 0.1031 - accuracy: 0.9787 - categorical_crossentropy: 0.4038 - val_loss: 0.1036 - val_accuracy: 0.9802 - val_categorical_crossentropy: 0.4058
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.1000 - accuracy: 0.9810 - categorical_crossentropy: 0.3834 - val_loss: 0.1006 - val_accuracy: 0.9817 - val_categorical_crossentropy: 0.3859
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0970 - accuracy: 0.9831 - categorical_crossentropy: 0.3629 - val_loss: 0.0977 - val_accuracy: 0.9832 - val_categorical_crossentropy: 0.3662
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0939 - accuracy: 0.9845 - categorical_crossentropy: 0.3426 - val_loss: 0.0949 - val_accuracy: 0.9849 - val_categorical_crossentropy: 0.3468
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0910 - accuracy: 0.9860 - categorical_crossentropy: 0.3227 - val_loss: 0.0921 - val_accuracy: 0.9860 - val_categorical_crossentropy: 0.3286
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0882 - accuracy: 0.9871 - categorical_crossentropy: 0.3038 - val_loss: 0.0894 - val_accuracy: 0.9874 - val_categorical_crossentropy: 0.3102
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0855 - accuracy: 0.9882 - categorical_crossentropy: 0.2860 - val_loss: 0.0869 - val_accuracy: 0.9880 - val_categorical_crossentropy: 0.2923
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0830 - accuracy: 0.9891 - categorical_crossentropy: 0.2682 - val_loss: 0.0845 - val_accuracy: 0.9887 - val_categorical_crossentropy: 0.2757
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0805 - accuracy: 0.9895 - categorical_crossentropy: 0.2517 - val_loss: 0.0822 - val_accuracy: 0.9895 - val_categorical_crossentropy: 0.2604
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0782 - accuracy: 0.9903 - categorical_crossentropy: 0.2362 - val_loss: 0.0800 - val_accuracy: 0.9904 - val_categorical_crossentropy: 0.2444
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0761 - accuracy: 0.9911 - categorical_crossentropy: 0.2211 - val_loss: 0.0778 - val_accuracy: 0.9914 - val_categorical_crossentropy: 0.2291
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0740 - accuracy: 0.9917 - categorical_crossentropy: 0.2070 - val_loss: 0.0758 - val_accuracy: 0.9919 - val_categorical_crossentropy: 0.2153
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0721 - accuracy: 0.9927 - categorical_crossentropy: 0.1935 - val_loss: 0.0740 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.2032
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0702 - accuracy: 0.9934 - categorical_crossentropy: 0.1811 - val_loss: 0.0721 - val_accuracy: 0.9930 - val_categorical_crossentropy: 0.1895
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0684 - accuracy: 0.9940 - categorical_crossentropy: 0.1689 - val_loss: 0.0704 - val_accuracy: 0.9938 - val_categorical_crossentropy: 0.1773
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0668 - accuracy: 0.9947 - categorical_crossentropy: 0.1576 - val_loss: 0.0687 - val_accuracy: 0.9943 - val_categorical_crossentropy: 0.1659
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0652 - accuracy: 0.9953 - categorical_crossentropy: 0.1465 - val_loss: 0.0671 - val_accuracy: 0.9950 - val_categorical_crossentropy: 0.1544
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0637 - accuracy: 0.9958 - categorical_crossentropy: 0.1366 - val_loss: 0.0656 - val_accuracy: 0.9953 - val_categorical_crossentropy: 0.1440
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0623 - accuracy: 0.9962 - categorical_crossentropy: 0.1272 - val_loss: 0.0642 - val_accuracy: 0.9956 - val_categorical_crossentropy: 0.1345
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0610 - accuracy: 0.9964 - categorical_crossentropy: 0.1184 - val_loss: 0.0629 - val_accuracy: 0.9958 - val_categorical_crossentropy: 0.1258
# Epoch 6/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0598 - accuracy: 0.9967 - categorical_crossentropy: 0.1100 - val_loss: 0.0617 - val_accuracy: 0.9961 - val_categorical_crossentropy: 0.1173
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0586 - accuracy: 0.9970 - categorical_crossentropy: 0.1024 - val_loss: 0.0605 - val_accuracy: 0.9965 - val_categorical_crossentropy: 0.1093
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0576 - accuracy: 0.9972 - categorical_crossentropy: 0.0953 - val_loss: 0.0595 - val_accuracy: 0.9966 - val_categorical_crossentropy: 0.1022
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0566 - accuracy: 0.9974 - categorical_crossentropy: 0.0886 - val_loss: 0.0584 - val_accuracy: 0.9968 - val_categorical_crossentropy: 0.0949
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0556 - accuracy: 0.9976 - categorical_crossentropy: 0.0824 - val_loss: 0.0575 - val_accuracy: 0.9969 - val_categorical_crossentropy: 0.0887
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0548 - accuracy: 0.9977 - categorical_crossentropy: 0.0767 - val_loss: 0.0566 - val_accuracy: 0.9973 - val_categorical_crossentropy: 0.0825
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0540 - accuracy: 0.9980 - categorical_crossentropy: 0.0715 - val_loss: 0.0558 - val_accuracy: 0.9976 - val_categorical_crossentropy: 0.0772
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0532 - accuracy: 0.9981 - categorical_crossentropy: 0.0667 - val_loss: 0.0550 - val_accuracy: 0.9977 - val_categorical_crossentropy: 0.0725
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0525 - accuracy: 0.9982 - categorical_crossentropy: 0.0625 - val_loss: 0.0543 - val_accuracy: 0.9977 - val_categorical_crossentropy: 0.0678
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0519 - accuracy: 0.9983 - categorical_crossentropy: 0.0584 - val_loss: 0.0536 - val_accuracy: 0.9978 - val_categorical_crossentropy: 0.0635
# Epoch 6/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0513 - accuracy: 0.9984 - categorical_crossentropy: 0.0547 - val_loss: 0.0531 - val_accuracy: 0.9980 - val_categorical_crossentropy: 0.0600
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0508 - accuracy: 0.9986 - categorical_crossentropy: 0.0512 - val_loss: 0.0525 - val_accuracy: 0.9983 - val_categorical_crossentropy: 0.0563
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0503 - accuracy: 0.9988 - categorical_crossentropy: 0.0481 - val_loss: 0.0520 - val_accuracy: 0.9985 - val_categorical_crossentropy: 0.0530
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0498 - accuracy: 0.9990 - categorical_crossentropy: 0.0452 - val_loss: 0.0515 - val_accuracy: 0.9988 - val_categorical_crossentropy: 0.0499
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0494 - accuracy: 0.9992 - categorical_crossentropy: 0.0426 - val_loss: 0.0511 - val_accuracy: 0.9989 - val_categorical_crossentropy: 0.0472
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0490 - accuracy: 0.9992 - categorical_crossentropy: 0.0401 - val_loss: 0.0507 - val_accuracy: 0.9990 - val_categorical_crossentropy: 0.0447
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0486 - accuracy: 0.9993 - categorical_crossentropy: 0.0379 - val_loss: 0.0503 - val_accuracy: 0.9992 - val_categorical_crossentropy: 0.0422
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0483 - accuracy: 0.9994 - categorical_crossentropy: 0.0357 - val_loss: 0.0499 - val_accuracy: 0.9994 - val_categorical_crossentropy: 0.0401
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0480 - accuracy: 0.9995 - categorical_crossentropy: 0.0338 - val_loss: 0.0496 - val_accuracy: 0.9994 - val_categorical_crossentropy: 0.0379
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0477 - accuracy: 0.9995 - categorical_crossentropy: 0.0320 - val_loss: 0.0493 - val_accuracy: 0.9995 - val_categorical_crossentropy: 0.0361
# Epoch 6/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0474 - accuracy: 0.9995 - categorical_crossentropy: 0.0302 - val_loss: 0.0490 - val_accuracy: 0.9995 - val_categorical_crossentropy: 0.0343
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0471 - accuracy: 0.9996 - categorical_crossentropy: 0.0288 - val_loss: 0.0487 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0327
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0469 - accuracy: 0.9996 - categorical_crossentropy: 0.0273 - val_loss: 0.0485 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0311
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0467 - accuracy: 0.9996 - categorical_crossentropy: 0.0259 - val_loss: 0.0482 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0298
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0465 - accuracy: 0.9996 - categorical_crossentropy: 0.0247 - val_loss: 0.0480 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0286
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0463 - accuracy: 0.9996 - categorical_crossentropy: 0.0236 - val_loss: 0.0478 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0274
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0461 - accuracy: 0.9996 - categorical_crossentropy: 0.0225 - val_loss: 0.0477 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0262
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0460 - accuracy: 0.9996 - categorical_crossentropy: 0.0215 - val_loss: 0.0475 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0253
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0458 - accuracy: 0.9996 - categorical_crossentropy: 0.0206 - val_loss: 0.0473 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0242
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0456 - accuracy: 0.9996 - categorical_crossentropy: 0.0196 - val_loss: 0.0472 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0233
# Epoch 6/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0455 - accuracy: 0.9997 - categorical_crossentropy: 0.0188 - val_loss: 0.0470 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0224
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0454 - accuracy: 0.9997 - categorical_crossentropy: 0.0180 - val_loss: 0.0469 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0216
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0452 - accuracy: 0.9997 - categorical_crossentropy: 0.0173 - val_loss: 0.0467 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0209
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0451 - accuracy: 0.9997 - categorical_crossentropy: 0.0166 - val_loss: 0.0466 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0202
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0450 - accuracy: 0.9997 - categorical_crossentropy: 0.0159 - val_loss: 0.0465 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0195
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0449 - accuracy: 0.9998 - categorical_crossentropy: 0.0153 - val_loss: 0.0464 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0189
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0448 - accuracy: 0.9998 - categorical_crossentropy: 0.0147 - val_loss: 0.0463 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0183
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0447 - accuracy: 0.9998 - categorical_crossentropy: 0.0142 - val_loss: 0.0462 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0178
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0446 - accuracy: 0.9998 - categorical_crossentropy: 0.0137 - val_loss: 0.0461 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0172
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0445 - accuracy: 0.9998 - categorical_crossentropy: 0.0132 - val_loss: 0.0460 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0168
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0445 - accuracy: 0.9998 - categorical_crossentropy: 0.0127 - val_loss: 0.0460 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0163
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0444 - accuracy: 0.9998 - categorical_crossentropy: 0.0123 - val_loss: 0.0459 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0158
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0443 - accuracy: 0.9998 - categorical_crossentropy: 0.0119 - val_loss: 0.0458 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0154
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0442 - accuracy: 0.9998 - categorical_crossentropy: 0.0115 - val_loss: 0.0457 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0150
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0442 - accuracy: 0.9998 - categorical_crossentropy: 0.0110 - val_loss: 0.0457 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0146
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0441 - accuracy: 0.9998 - categorical_crossentropy: 0.0107 - val_loss: 0.0456 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0142
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0440 - accuracy: 0.9998 - categorical_crossentropy: 0.0103 - val_loss: 0.0455 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0138
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0440 - accuracy: 0.9998 - categorical_crossentropy: 0.0100 - val_loss: 0.0455 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0135
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0439 - accuracy: 0.9998 - categorical_crossentropy: 0.0097 - val_loss: 0.0454 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0132
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0439 - accuracy: 0.9998 - categorical_crossentropy: 0.0094 - val_loss: 0.0454 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0129
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0438 - accuracy: 0.9998 - categorical_crossentropy: 0.0091 - val_loss: 0.0453 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0126
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0438 - accuracy: 0.9999 - categorical_crossentropy: 0.0089 - val_loss: 0.0453 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0123
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0437 - accuracy: 0.9999 - categorical_crossentropy: 0.0086 - val_loss: 0.0452 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0120
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0437 - accuracy: 0.9999 - categorical_crossentropy: 0.0083 - val_loss: 0.0452 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0117
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0436 - accuracy: 0.9999 - categorical_crossentropy: 0.0081 - val_loss: 0.0451 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0115
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0436 - accuracy: 0.9999 - categorical_crossentropy: 0.0079 - val_loss: 0.0451 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0113
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0436 - accuracy: 0.9999 - categorical_crossentropy: 0.0076 - val_loss: 0.0450 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0110
# Epoch 3/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0435 - accuracy: 1.0000 - categorical_crossentropy: 0.0075 - val_loss: 0.0450 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0108
# Epoch 4/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0435 - accuracy: 1.0000 - categorical_crossentropy: 0.0072 - val_loss: 0.0450 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0106
# Epoch 5/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0434 - accuracy: 1.0000 - categorical_crossentropy: 0.0071 - val_loss: 0.0449 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0104
# Epoch 6/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0434 - accuracy: 1.0000 - categorical_crossentropy: 0.0068 - val_loss: 0.0449 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0102
# Epoch 7/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0434 - accuracy: 1.0000 - categorical_crossentropy: 0.0067 - val_loss: 0.0448 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0100
# Epoch 8/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0433 - accuracy: 1.0000 - categorical_crossentropy: 0.0065 - val_loss: 0.0448 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0098
# Epoch 9/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0433 - accuracy: 1.0000 - categorical_crossentropy: 0.0064 - val_loss: 0.0448 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0096
# Epoch 10/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0433 - accuracy: 1.0000 - categorical_crossentropy: 0.0062 - val_loss: 0.0448 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0095

# %%
pitch_bidirectional = getModel(timesteps, pitch_num_features, bidirectional=True)
trainModel(pitch_bidirectional, pitch_X_train, pitch_Y_train)
# Out:
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 8s 27ms/sample - loss: 0.0867 - accuracy: 0.9836 - categorical_crossentropy: 1.9486 - val_loss: 0.0847 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.8840
# Epoch 2/10
# 294/294 [==============================] - 2s 7ms/sample - loss: 0.0855 - accuracy: 0.9836 - categorical_crossentropy: 1.9091 - val_loss: 0.0834 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.8387
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0838 - accuracy: 0.9836 - categorical_crossentropy: 1.8557 - val_loss: 0.0811 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.7631
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0808 - accuracy: 0.9836 - categorical_crossentropy: 1.7572 - val_loss: 0.0768 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.6241
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0766 - accuracy: 0.9836 - categorical_crossentropy: 1.6188 - val_loss: 0.0727 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.4909
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0730 - accuracy: 0.9836 - categorical_crossentropy: 1.5032 - val_loss: 0.0698 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.3960
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0704 - accuracy: 0.9836 - categorical_crossentropy: 1.4172 - val_loss: 0.0680 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.3346
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0690 - accuracy: 0.9836 - categorical_crossentropy: 1.3685 - val_loss: 0.0668 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.2957
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0677 - accuracy: 0.9836 - categorical_crossentropy: 1.3301 - val_loss: 0.0655 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.2573
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0665 - accuracy: 0.9836 - categorical_crossentropy: 1.2938 - val_loss: 0.0643 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.2218
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0654 - accuracy: 0.9836 - categorical_crossentropy: 1.2598 - val_loss: 0.0632 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.1882
# Epoch 2/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0642 - accuracy: 0.9836 - categorical_crossentropy: 1.2253 - val_loss: 0.0621 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.1536
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0630 - accuracy: 0.9836 - categorical_crossentropy: 1.1885 - val_loss: 0.0608 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.1165
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0616 - accuracy: 0.9836 - categorical_crossentropy: 1.1496 - val_loss: 0.0594 - val_accuracy: 0.9839 - val_categorical_crossentropy: 1.0772
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0602 - accuracy: 0.9836 - categorical_crossentropy: 1.1083 - val_loss: 0.0580 - val_accuracy: 0.9840 - val_categorical_crossentropy: 1.0383
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0587 - accuracy: 0.9836 - categorical_crossentropy: 1.0655 - val_loss: 0.0566 - val_accuracy: 0.9840 - val_categorical_crossentropy: 0.9963
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0571 - accuracy: 0.9836 - categorical_crossentropy: 1.0211 - val_loss: 0.0550 - val_accuracy: 0.9840 - val_categorical_crossentropy: 0.9543
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0555 - accuracy: 0.9837 - categorical_crossentropy: 0.9757 - val_loss: 0.0534 - val_accuracy: 0.9842 - val_categorical_crossentropy: 0.9099
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0538 - accuracy: 0.9839 - categorical_crossentropy: 0.9291 - val_loss: 0.0517 - val_accuracy: 0.9845 - val_categorical_crossentropy: 0.8632
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0520 - accuracy: 0.9843 - categorical_crossentropy: 0.8824 - val_loss: 0.0499 - val_accuracy: 0.9848 - val_categorical_crossentropy: 0.8154
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0502 - accuracy: 0.9848 - categorical_crossentropy: 0.8341 - val_loss: 0.0481 - val_accuracy: 0.9855 - val_categorical_crossentropy: 0.7676
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0484 - accuracy: 0.9855 - categorical_crossentropy: 0.7846 - val_loss: 0.0463 - val_accuracy: 0.9866 - val_categorical_crossentropy: 0.7210
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0465 - accuracy: 0.9869 - categorical_crossentropy: 0.7371 - val_loss: 0.0444 - val_accuracy: 0.9877 - val_categorical_crossentropy: 0.6729
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0446 - accuracy: 0.9879 - categorical_crossentropy: 0.6877 - val_loss: 0.0425 - val_accuracy: 0.9890 - val_categorical_crossentropy: 0.6256
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0426 - accuracy: 0.9894 - categorical_crossentropy: 0.6400 - val_loss: 0.0405 - val_accuracy: 0.9902 - val_categorical_crossentropy: 0.5781
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0407 - accuracy: 0.9905 - categorical_crossentropy: 0.5924 - val_loss: 0.0386 - val_accuracy: 0.9913 - val_categorical_crossentropy: 0.5317
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0388 - accuracy: 0.9918 - categorical_crossentropy: 0.5468 - val_loss: 0.0368 - val_accuracy: 0.9925 - val_categorical_crossentropy: 0.4881
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0369 - accuracy: 0.9927 - categorical_crossentropy: 0.5032 - val_loss: 0.0349 - val_accuracy: 0.9935 - val_categorical_crossentropy: 0.4455
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0351 - accuracy: 0.9937 - categorical_crossentropy: 0.4617 - val_loss: 0.0332 - val_accuracy: 0.9945 - val_categorical_crossentropy: 0.4058
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0334 - accuracy: 0.9946 - categorical_crossentropy: 0.4224 - val_loss: 0.0316 - val_accuracy: 0.9954 - val_categorical_crossentropy: 0.3688
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0318 - accuracy: 0.9954 - categorical_crossentropy: 0.3862 - val_loss: 0.0300 - val_accuracy: 0.9961 - val_categorical_crossentropy: 0.3346
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0303 - accuracy: 0.9960 - categorical_crossentropy: 0.3531 - val_loss: 0.0286 - val_accuracy: 0.9966 - val_categorical_crossentropy: 0.3032
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0289 - accuracy: 0.9964 - categorical_crossentropy: 0.3224 - val_loss: 0.0273 - val_accuracy: 0.9971 - val_categorical_crossentropy: 0.2740
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0276 - accuracy: 0.9968 - categorical_crossentropy: 0.2940 - val_loss: 0.0261 - val_accuracy: 0.9974 - val_categorical_crossentropy: 0.2471
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0264 - accuracy: 0.9971 - categorical_crossentropy: 0.2684 - val_loss: 0.0250 - val_accuracy: 0.9977 - val_categorical_crossentropy: 0.2233
# Epoch 6/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0254 - accuracy: 0.9974 - categorical_crossentropy: 0.2452 - val_loss: 0.0239 - val_accuracy: 0.9979 - val_categorical_crossentropy: 0.2016
# Epoch 7/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0244 - accuracy: 0.9977 - categorical_crossentropy: 0.2243 - val_loss: 0.0230 - val_accuracy: 0.9982 - val_categorical_crossentropy: 0.1824
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0235 - accuracy: 0.9979 - categorical_crossentropy: 0.2059 - val_loss: 0.0222 - val_accuracy: 0.9984 - val_categorical_crossentropy: 0.1651
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0227 - accuracy: 0.9981 - categorical_crossentropy: 0.1896 - val_loss: 0.0214 - val_accuracy: 0.9987 - val_categorical_crossentropy: 0.1501
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0220 - accuracy: 0.9984 - categorical_crossentropy: 0.1746 - val_loss: 0.0208 - val_accuracy: 0.9989 - val_categorical_crossentropy: 0.1366
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0213 - accuracy: 0.9986 - categorical_crossentropy: 0.1615 - val_loss: 0.0202 - val_accuracy: 0.9991 - val_categorical_crossentropy: 0.1249
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0208 - accuracy: 0.9988 - categorical_crossentropy: 0.1498 - val_loss: 0.0197 - val_accuracy: 0.9993 - val_categorical_crossentropy: 0.1143
# Epoch 3/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0203 - accuracy: 0.9989 - categorical_crossentropy: 0.1395 - val_loss: 0.0192 - val_accuracy: 0.9994 - val_categorical_crossentropy: 0.1050
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0198 - accuracy: 0.9991 - categorical_crossentropy: 0.1301 - val_loss: 0.0187 - val_accuracy: 0.9995 - val_categorical_crossentropy: 0.0965
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0194 - accuracy: 0.9992 - categorical_crossentropy: 0.1216 - val_loss: 0.0184 - val_accuracy: 0.9996 - val_categorical_crossentropy: 0.0889
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0190 - accuracy: 0.9992 - categorical_crossentropy: 0.1138 - val_loss: 0.0180 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0821
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0186 - accuracy: 0.9993 - categorical_crossentropy: 0.1067 - val_loss: 0.0177 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0761
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0183 - accuracy: 0.9994 - categorical_crossentropy: 0.1006 - val_loss: 0.0174 - val_accuracy: 0.9997 - val_categorical_crossentropy: 0.0707
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0180 - accuracy: 0.9994 - categorical_crossentropy: 0.0950 - val_loss: 0.0172 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0660
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0178 - accuracy: 0.9994 - categorical_crossentropy: 0.0899 - val_loss: 0.0169 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0617
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0176 - accuracy: 0.9995 - categorical_crossentropy: 0.0853 - val_loss: 0.0167 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0577
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0173 - accuracy: 0.9995 - categorical_crossentropy: 0.0809 - val_loss: 0.0165 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0541
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0171 - accuracy: 0.9995 - categorical_crossentropy: 0.0769 - val_loss: 0.0164 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0508
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0169 - accuracy: 0.9995 - categorical_crossentropy: 0.0732 - val_loss: 0.0162 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0477
# Epoch 5/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0168 - accuracy: 0.9996 - categorical_crossentropy: 0.0697 - val_loss: 0.0161 - val_accuracy: 0.9998 - val_categorical_crossentropy: 0.0451
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0166 - accuracy: 0.9996 - categorical_crossentropy: 0.0665 - val_loss: 0.0159 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0424
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0165 - accuracy: 0.9996 - categorical_crossentropy: 0.0635 - val_loss: 0.0158 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0401
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0163 - accuracy: 0.9996 - categorical_crossentropy: 0.0607 - val_loss: 0.0157 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0379
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0162 - accuracy: 0.9996 - categorical_crossentropy: 0.0580 - val_loss: 0.0156 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0360
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0161 - accuracy: 0.9996 - categorical_crossentropy: 0.0556 - val_loss: 0.0155 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0341
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0160 - accuracy: 0.9996 - categorical_crossentropy: 0.0534 - val_loss: 0.0154 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0323
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0159 - accuracy: 0.9996 - categorical_crossentropy: 0.0511 - val_loss: 0.0153 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0307
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0157 - accuracy: 0.9996 - categorical_crossentropy: 0.0490 - val_loss: 0.0152 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0292
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0157 - accuracy: 0.9996 - categorical_crossentropy: 0.0471 - val_loss: 0.0152 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0279
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0156 - accuracy: 0.9997 - categorical_crossentropy: 0.0453 - val_loss: 0.0151 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0266
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0155 - accuracy: 0.9997 - categorical_crossentropy: 0.0434 - val_loss: 0.0150 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0253
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0154 - accuracy: 0.9997 - categorical_crossentropy: 0.0416 - val_loss: 0.0150 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0242
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0153 - accuracy: 0.9997 - categorical_crossentropy: 0.0400 - val_loss: 0.0149 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0231
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0152 - accuracy: 0.9997 - categorical_crossentropy: 0.0386 - val_loss: 0.0148 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0221
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0152 - accuracy: 0.9997 - categorical_crossentropy: 0.0370 - val_loss: 0.0148 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0212
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0151 - accuracy: 0.9997 - categorical_crossentropy: 0.0357 - val_loss: 0.0147 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0204
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0150 - accuracy: 0.9997 - categorical_crossentropy: 0.0345 - val_loss: 0.0147 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0196
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0150 - accuracy: 0.9997 - categorical_crossentropy: 0.0332 - val_loss: 0.0147 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0188
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0149 - accuracy: 0.9997 - categorical_crossentropy: 0.0319 - val_loss: 0.0146 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0181
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0148 - accuracy: 0.9998 - categorical_crossentropy: 0.0308 - val_loss: 0.0146 - val_accuracy: 0.9999 - val_categorical_crossentropy: 0.0174
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0148 - accuracy: 0.9998 - categorical_crossentropy: 0.0298 - val_loss: 0.0145 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0168
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0147 - accuracy: 0.9998 - categorical_crossentropy: 0.0287 - val_loss: 0.0145 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0162
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0147 - accuracy: 0.9998 - categorical_crossentropy: 0.0278 - val_loss: 0.0145 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0156
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0146 - accuracy: 0.9998 - categorical_crossentropy: 0.0269 - val_loss: 0.0144 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0150
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0146 - accuracy: 0.9998 - categorical_crossentropy: 0.0260 - val_loss: 0.0144 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0145
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0146 - accuracy: 0.9998 - categorical_crossentropy: 0.0252 - val_loss: 0.0144 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0140
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0145 - accuracy: 0.9998 - categorical_crossentropy: 0.0243 - val_loss: 0.0144 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0135
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0145 - accuracy: 0.9998 - categorical_crossentropy: 0.0235 - val_loss: 0.0143 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0131
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0144 - accuracy: 0.9998 - categorical_crossentropy: 0.0228 - val_loss: 0.0143 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0127
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0144 - accuracy: 0.9999 - categorical_crossentropy: 0.0220 - val_loss: 0.0143 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0122
# Epoch 6/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0144 - accuracy: 0.9999 - categorical_crossentropy: 0.0212 - val_loss: 0.0143 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0118
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0143 - accuracy: 0.9999 - categorical_crossentropy: 0.0207 - val_loss: 0.0142 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0115
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0143 - accuracy: 0.9999 - categorical_crossentropy: 0.0200 - val_loss: 0.0142 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0111
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0143 - accuracy: 0.9999 - categorical_crossentropy: 0.0194 - val_loss: 0.0142 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0108
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0142 - accuracy: 0.9999 - categorical_crossentropy: 0.0188 - val_loss: 0.0142 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0105
# Train on 294 samples, validate on 74 samples
# Epoch 1/10
# 294/294 [==============================] - 3s 9ms/sample - loss: 0.0142 - accuracy: 0.9999 - categorical_crossentropy: 0.0183 - val_loss: 0.0142 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0102
# Epoch 2/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0142 - accuracy: 0.9999 - categorical_crossentropy: 0.0178 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0099
# Epoch 3/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0141 - accuracy: 0.9999 - categorical_crossentropy: 0.0172 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0096
# Epoch 4/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0141 - accuracy: 0.9999 - categorical_crossentropy: 0.0167 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0094
# Epoch 5/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0141 - accuracy: 0.9999 - categorical_crossentropy: 0.0161 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0091
# Epoch 6/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0141 - accuracy: 0.9999 - categorical_crossentropy: 0.0156 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0089
# Epoch 7/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0140 - accuracy: 0.9999 - categorical_crossentropy: 0.0151 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0086
# Epoch 8/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0140 - accuracy: 0.9999 - categorical_crossentropy: 0.0146 - val_loss: 0.0141 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0083
# Epoch 9/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0140 - accuracy: 0.9999 - categorical_crossentropy: 0.0142 - val_loss: 0.0140 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0081
# Epoch 10/10
# 294/294 [==============================] - 2s 8ms/sample - loss: 0.0140 - accuracy: 0.9999 - categorical_crossentropy: 0.0138 - val_loss: 0.0140 - val_accuracy: 1.0000 - val_categorical_crossentropy: 0.0079

# %%
# model.predict requires 3D vector, so this reshapes a 2D input to 3D so it can be fed through the network
def to_3D(sample):
    return sample.reshape(1, sample.shape[0], sample.shape[1])

# %%
# converts output one-hot vectors to its respective quarter length value (based on durations seen in data set)
def duration_one_hot_to_quarter_length(prediction):
    new_durations = []
    for timestep in prediction:
        index = np.argmax(timestep)
        new_durations.append(durations[index])
    
    return new_durations

# converts output one-hot vectors to its respective MIDI pitch value (based on durations seen in data set)
def pitch_one_hot_to_MIDI(prediction):
    new_pitches = []
    for timestep in prediction:
        index = np.argmax(timestep)
        new_pitches.append(pitches[index])
    
    return new_pitches

# %%
duration_pred = duration_bidirectional.predict(to_3D(duration_X_test[0])).reshape(timesteps, duration_num_features)
composed_durations = duration_one_hot_to_quarter_length(duration_pred)

pitch_pred = pitch_bidirectional.predict(to_3D(pitch_X_test[0])).reshape(timesteps, pitch_num_features)
composed_pitches = pitch_one_hot_to_MIDI(pitch_pred)

# %%
#Returns a list of tuples of composed notes in sequence [(64, 2.0), (x,y), ...]
composed_pairs = list(zip(composed_pitches, composed_durations))

composed_stream = stream.Stream()
for pair in composed_pairs:
    p = pitch.Pitch(midi=pair[0])
    d = duration.Duration(pair[1])
    n = note.Note()
    n.pitch = p
    n.duration = d
    composed_stream.append(n)

# %%
composed_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv638'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv638');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
composed_stream.show()
