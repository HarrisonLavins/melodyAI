# %%
from music21 import *
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Feature Extraction
# Features extracted:
# - MIDI pitches
# - Rhythms
# - Chords (roman numerals)

# %%
# Extract features from the corpus and place each piece in the chorales_train variable
# --------------------------------------------------------------------------------
bachCorpus = corpus.getComposer('bach')
chorales_notes_train = [] #all chorale note tuples stored as a list
chorales_chords_train = [] #all chorale chord sequences stored as a list

# Keep track of all features encountered
all_durations = []
all_notes = []
all_chords = []

for piece in bachCorpus:    
    pieceScore = corpus.parse(piece)  # stream.Score object
    melodyPart = pieceScore.getElementsByClass('Part')[0]  # melody parts are always the first part in the score
    melodyNotes = melodyPart.flat.getElementsByClass('Note') #extract all notes in the part
    
    print('Processing chorale: {}'.format(pieceScore.metadata.title))

    
    #Chordify and extract chord sequences
    # ---------------------------------->
    bChords = pieceScore.chordify()
    #Condense all chords into the middle range of treble clef 
    for c in bChords.recurse().getElementsByClass('Chord'):
        c.closedPosition(forceOctave=4, inPlace=True)
        
    #Analyze roman numerals
    bKey = None
    for keychange in melodyPart.recurse().getElementsByClass(key.Key):
        #Get key of piece (for chord context)
        bKey = keychange
    for c in bChords.recurse().getElementsByClass('Chord'):
        rn = roman.romanNumeralFromChord(c, bKey)
        c.addLyric(str(rn.figure))
    
    #Collect chord sequence in a list
    chordSequence = []
    for c in bChords.flat:
        if 'Chord' not in c.classes:
            continue
        chordSequence.append(c.lyric)
        all_chords.append(c.lyric) #keep a running total of all chords seen
    
    chorales_chords_train.append(chordSequence) #store this piece's chord sequence in master list
    
    
    #Extract note pitches and rhythms
    # --------------------------------
    noteSequence = [] #series of all notes in order, from start to end of piece
    for n in melodyNotes.recurse():  # iterates through all notes in the piece
        midiNote = n.pitch.midi
        noteDuration = n.duration.quarterLength
        noteTuple = (midiNote, noteDuration) # (MIDI_pitch, note_duration)
        
        # Keep track of all notes and durations seen thus far
        all_durations.append(noteDuration) 
        all_notes.append(midiNote)
            
        noteSequence.append(noteTuple) # appends the next time step to the sample
        
    chorales_notes_train.append(noteSequence) #store this piece's sequence of notes in master list
# Out:
# Processing chorale: bwv1.6.mxl
# Processing chorale: bwv10.7.mxl
# Processing chorale: bwv101.7.mxl
# Processing chorale: bwv102.7.mxl
# Processing chorale: bwv103.6.mxl
# Processing chorale: bwv104.6.mxl
# Processing chorale: bwv108.6.mxl
# Processing chorale: bwv11.6.mxl
# Processing chorale: bwv110.7.mxl
# Processing chorale: bwv111.6.mxl
# Processing chorale: bwv112.5-sc.mxl
# Processing chorale: bwv112.5.mxl
# Processing chorale: bwv113.8.mxl
# Processing chorale: bwv114.7.mxl
# Processing chorale: bwv115.6.mxl
# Processing chorale: bwv116.6.mxl
# Processing chorale: bwv117.4.mxl
# Processing chorale: bwv119.9.mxl
# Processing chorale: bwv12.7.mxl
# Processing chorale: bwv120.6.mxl
# Processing chorale: bwv120.8-a.mxl
# Processing chorale: bwv121.6.mxl
# Processing chorale: bwv122.6.mxl
# Processing chorale: bwv123.6.mxl
# Processing chorale: bwv124.6.mxl
# Processing chorale: bwv125.6.mxl
# Processing chorale: bwv126.6.mxl
# Processing chorale: bwv127.5.mxl
# Processing chorale: bwv128.5.mxl
# Processing chorale: bwv13.6.mxl
# Processing chorale: bwv130.6.mxl
# Processing chorale: bwv133.6.mxl
# Processing chorale: bwv135.6.mxl
# Processing chorale: bwv136.6.mxl
# Processing chorale: bwv137.5.mxl
# Processing chorale: bwv139.6.mxl
# Processing chorale: bwv14.5.mxl
# Processing chorale: bwv140.7.mxl
# Processing chorale: bwv144.3.mxl
# Processing chorale: bwv144.6.mxl
# Processing chorale: bwv145-a.mxl
# Processing chorale: bwv145.5.mxl
# Processing chorale: bwv146.8.mxl
# Processing chorale: bwv148.6.mxl
# Processing chorale: bwv149.7.mxl
# Processing chorale: bwv151.5.mxl
# Processing chorale: bwv153.1.mxl
# Processing chorale: bwv153.5.mxl
# Processing chorale: bwv153.9.mxl
# Processing chorale: bwv154.3.mxl
# Processing chorale: bwv154.8.mxl
# Processing chorale: bwv155.5.mxl
# Processing chorale: bwv156.6.mxl
# Processing chorale: bwv157.5.mxl
# Processing chorale: bwv158.4.mxl
# Processing chorale: bwv159.5.mxl
# Processing chorale: bwv16.6.mxl
# Processing chorale: bwv161.6.mxl
# Processing chorale: bwv162.6-lpz.mxl
# Processing chorale: bwv164.6.mxl
# Processing chorale: bwv165.6.mxl
# Processing chorale: bwv166.6.mxl
# Processing chorale: bwv168.6.mxl
# Processing chorale: bwv169.7.mxl
# Processing chorale: bwv17.7.mxl
# Processing chorale: bwv171.6.mxl
# Processing chorale: bwv172.6.mxl
# Processing chorale: bwv174.5.mxl
# Processing chorale: bwv175.7.mxl
# Processing chorale: bwv176.6.mxl
# Processing chorale: bwv177.4.mxl
# Processing chorale: bwv177.5.mxl
# Processing chorale: bwv178.7.mxl
# Processing chorale: bwv179.6.mxl
# Processing chorale: bwv18.5-lz.mxl
# Processing chorale: bwv18.5-w.mxl
# Processing chorale: bwv180.7.mxl
# Processing chorale: bwv183.5.mxl
# Processing chorale: bwv184.5.mxl
# Processing chorale: bwv185.6.mxl
# Processing chorale: bwv187.7.mxl
# Processing chorale: bwv188.6.mxl
# Processing chorale: bwv19.7.mxl
# Processing chorale: bwv190.7-inst.mxl
# Processing chorale: bwv190.7.mxl
# Processing chorale: bwv194.12.mxl
# Processing chorale: bwv194.6.mxl
# Processing chorale: bwv195.6.mxl
# Processing chorale: bwv197.10.mxl
# Processing chorale: bwv197.5.mxl
# Processing chorale: bwv197.7-a.mxl
# Processing chorale: bwv2.6.mxl
# Processing chorale: bwv20.11.mxl
# Processing chorale: bwv20.7.mxl
# Processing chorale: bwv226.2.mxl
# Processing chorale: bwv227.1.mxl
# Processing chorale: bwv227.11.mxl
# Processing chorale: bwv227.3.mxl
# Processing chorale: bwv227.7.mxl
# Processing chorale: bwv229.2.mxl
# Processing chorale: bwv24.6.mxl
# Processing chorale: bwv244.10.mxl
# Processing chorale: bwv244.15.mxl
# Processing chorale: bwv244.17.mxl
# Processing chorale: bwv244.25.mxl
# Processing chorale: bwv244.29-a.mxl
# Processing chorale: bwv244.3.mxl
# Processing chorale: bwv244.32.mxl
# Processing chorale: bwv244.37.mxl
# Processing chorale: bwv244.40.mxl
# Processing chorale: bwv244.44.mxl
# Processing chorale: bwv244.46.mxl
# Processing chorale: bwv244.54.mxl
# Processing chorale: bwv244.62.mxl
# Processing chorale: bwv245.11.mxl
# Processing chorale: bwv245.14.mxl
# Processing chorale: bwv245.15.mxl
# Processing chorale: bwv245.17.mxl
# Processing chorale: bwv245.22.mxl
# Processing chorale: bwv245.26.mxl
# Processing chorale: bwv245.28.mxl
# Processing chorale: bwv245.3.mxl
# Processing chorale: bwv245.37.mxl
# Processing chorale: bwv245.40.mxl
# Processing chorale: bwv245.5.mxl
# Processing chorale: bwv248.12-2.mxl
# Processing chorale: bwv248.17.mxl
# Processing chorale: bwv248.23-2.mxl
# Processing chorale: bwv248.23-s.mxl
# Processing chorale: bwv248.28.mxl
# Processing chorale: bwv248.33-3.mxl
# Processing chorale: bwv248.35-3.mxl
# Processing chorale: bwv248.35-3c.mxl
# Processing chorale: bwv248.42-4.mxl
# Processing chorale: bwv248.42-s.mxl
# Processing chorale: bwv248.46-5.mxl
# Processing chorale: bwv248.5.mxl
# Processing chorale: bwv248.53-5.mxl
# Processing chorale: bwv248.59-6.mxl
# Processing chorale: bwv248.64-6.mxl
# Processing chorale: bwv248.64-s.mxl
# Processing chorale: bwv248.9-1.mxl
# Processing chorale: bwv248.9-s.mxl
# Processing chorale: bwv25.6.mxl
# Processing chorale: bwv250.mxl
# Processing chorale: bwv251.mxl
# Processing chorale: bwv252.mxl
# Processing chorale: bwv253.mxl
# Processing chorale: bwv254.mxl
# Processing chorale: bwv255.mxl
# Processing chorale: bwv256.mxl
# Processing chorale: bwv257.mxl
# Processing chorale: bwv258.mxl
# Processing chorale: bwv259.mxl
# Processing chorale: bwv26.6.mxl
# Processing chorale: bwv260.mxl
# Processing chorale: bwv261.mxl
# Processing chorale: bwv262.mxl
# Processing chorale: bwv263.mxl
# Processing chorale: bwv264.mxl
# Processing chorale: bwv265.mxl
# Processing chorale: bwv266.mxl
# Processing chorale: bwv267.mxl
# Processing chorale: bwv268.mxl
# Processing chorale: bwv269.mxl
# Processing chorale: bwv27.6.mxl
# Processing chorale: bwv270.mxl
# Processing chorale: bwv271.mxl
# Processing chorale: bwv272.mxl
# Processing chorale: bwv273.mxl
# Processing chorale: bwv274.mxl
# Processing chorale: bwv275.mxl
# Processing chorale: bwv276.mxl
# Processing chorale: 25. Christ lag in Todesbanden
# Processing chorale: bwv277.mxl
# Processing chorale: bwv278.mxl
# Processing chorale: bwv279.mxl
# Processing chorale: bwv28.6.mxl
# Processing chorale: bwv280.mxl
# Processing chorale: 28. Christus, der ist mein Leben
# Processing chorale: bwv281.mxl
# Processing chorale: bwv282.mxl
# Processing chorale: bwv283.mxl
# Processing chorale: bwv284.mxl
# Processing chorale: bwv285.mxl
# Processing chorale: bwv286.mxl
# Processing chorale: bwv287.mxl
# Processing chorale: bwv288.mxl
# Processing chorale: bwv289.mxl
# Processing chorale: bwv29.8.mxl
# Processing chorale: bwv290.mxl
# Processing chorale: bwv291.mxl
# Processing chorale: bwv292.mxl
# Processing chorale: bwv293.mxl
# Processing chorale: bwv294.mxl
# Processing chorale: bwv295.mxl
# Processing chorale: bwv296.mxl
# Processing chorale: bwv297.mxl
# Processing chorale: bwv298.mxl
# Processing chorale: bwv299.mxl
# Processing chorale: bwv3.6.mxl
# Processing chorale: bwv30.6.mxl
# Processing chorale: bwv300.mxl
# Processing chorale: bwv301.mxl
# Processing chorale: bwv302.mxl
# Processing chorale: bwv303.mxl
# Processing chorale: bwv304.mxl
# Processing chorale: bwv305.mxl
# Processing chorale: bwv306.mxl
# Processing chorale: bwv307.mxl
# Processing chorale: bwv308.mxl
# Processing chorale: bwv309.mxl
# Processing chorale: bwv31.9.mxl
# Processing chorale: bwv310.mxl
# Processing chorale: bwv311.mxl
# Processing chorale: bwv312.mxl
# Processing chorale: bwv313.mxl
# Processing chorale: bwv314.mxl
# Processing chorale: bwv315.mxl
# Processing chorale: bwv316.mxl
# Processing chorale: bwv317.mxl
# Processing chorale: bwv318.mxl
# Processing chorale: bwv319.mxl
# Processing chorale: bwv32.6.mxl
# Processing chorale: bwv320.mxl
# Processing chorale: bwv321.mxl
# Processing chorale: bwv322.mxl
# Processing chorale: bwv323.mxl
# Processing chorale: bwv324.mxl
# Processing chorale: bwv325.mxl
# Processing chorale: bwv326.mxl
# Processing chorale: bwv327.mxl
# Processing chorale: bwv328.mxl
# Processing chorale: bwv329.mxl
# Processing chorale: bwv33.6.mxl
# Processing chorale: bwv330.mxl
# Processing chorale: bwv331.mxl
# Processing chorale: bwv332.mxl
# Processing chorale: bwv333.mxl
# Processing chorale: bwv334.mxl
# Processing chorale: bwv335.mxl
# Processing chorale: bwv336.mxl
# Processing chorale: bwv337.mxl
# Processing chorale: bwv338.mxl
# Processing chorale: bwv339.mxl
# Processing chorale: bwv340.mxl
# Processing chorale: bwv341.mxl
# Processing chorale: bwv342.mxl
# Processing chorale: bwv343.mxl
# Processing chorale: bwv344.mxl
# Processing chorale: bwv345.mxl
# Processing chorale: bwv346.mxl
# Processing chorale: bwv347.mxl
# Processing chorale: bwv348.mxl
# Processing chorale: bwv349.mxl
# Processing chorale: bwv350.mxl
# Processing chorale: bwv351.mxl
# Processing chorale: bwv352.mxl
# Processing chorale: bwv353.mxl
# Processing chorale: bwv354.mxl
# Processing chorale: bwv355.mxl
# Processing chorale: bwv356.mxl
# Processing chorale: bwv357.mxl
# Processing chorale: bwv358.mxl
# Processing chorale: bwv359.mxl
# Processing chorale: bwv36.4-2.mxl
# Processing chorale: bwv36.8-2.mxl
# Processing chorale: bwv360.mxl
# Processing chorale: bwv361.mxl
# Processing chorale: bwv362.mxl
# Processing chorale: bwv363.mxl
# Processing chorale: bwv364.mxl
# Processing chorale: bwv365.mxl
# Processing chorale: 113. Ihr Gestirn', ihr hohen L\u3fte
# Processing chorale: bwv366.mxl
# Processing chorale: bwv367.mxl
# Processing chorale: bwv368.mxl
# Processing chorale: bwv369.mxl
# Processing chorale: bwv37.6.mxl
# Processing chorale: bwv370.mxl
# Processing chorale: bwv371.mxl
# Processing chorale: bwv372.mxl
# Processing chorale: bwv373.mxl
# Processing chorale: bwv374.mxl
# Processing chorale: bwv375.mxl
# Processing chorale: bwv376.mxl
# Processing chorale: bwv377.mxl
# Processing chorale: bwv378.mxl
# Processing chorale: bwv379.mxl
# Processing chorale: bwv38.6.mxl
# Processing chorale: bwv380.mxl
# Processing chorale: bwv381.mxl
# Processing chorale: bwv382.mxl
# Processing chorale: bwv383.mxl
# Processing chorale: bwv384.mxl
# Processing chorale: bwv385.mxl
# Processing chorale: bwv386.mxl
# Processing chorale: bwv387.mxl
# Processing chorale: bwv388.mxl
# Processing chorale: bwv389.mxl
# Processing chorale: bwv39.7.mxl
# Processing chorale: bwv390.mxl
# Processing chorale: bwv391.mxl
# Processing chorale: bwv392.mxl
# Processing chorale: bwv393.mxl
# Processing chorale: bwv394.mxl
# Processing chorale: bwv395.mxl
# Processing chorale: bwv396.mxl
# Processing chorale: bwv397.mxl
# Processing chorale: bwv398.mxl
# Processing chorale: bwv399.mxl
# Processing chorale: bwv4.8.mxl
# Processing chorale: bwv40.3.mxl
# Processing chorale: bwv40.6.mxl
# Processing chorale: bwv40.8.mxl
# Processing chorale: bwv400.mxl
# Processing chorale: bwv401.mxl
# Processing chorale: bwv402.mxl
# Processing chorale: bwv403.mxl
# Processing chorale: bwv404.mxl
# Processing chorale: bwv405.mxl
# Processing chorale: bwv406.mxl
# Processing chorale: bwv407.mxl
# Processing chorale: bwv408.mxl
# Processing chorale: bwv409.mxl
# Processing chorale: bwv41.6.mxl
# Processing chorale: bwv410.mxl
# Processing chorale: bwv411.mxl
# Processing chorale: bwv412.mxl
# Processing chorale: bwv413.mxl
# Processing chorale: bwv414.mxl
# Processing chorale: bwv415.mxl
# Processing chorale: bwv416.mxl
# Processing chorale: bwv417.mxl
# Processing chorale: bwv418.mxl
# Processing chorale: bwv419.mxl
# Processing chorale: bwv42.7.mxl
# Processing chorale: bwv420.mxl
# Processing chorale: bwv421.mxl
# Processing chorale: bwv422.mxl
# Processing chorale: bwv423.mxl
# Processing chorale: bwv424.mxl
# Processing chorale: bwv425.mxl
# Processing chorale: bwv426.mxl
# Processing chorale: bwv427.mxl
# Processing chorale: bwv428.mxl
# Processing chorale: bwv429.mxl
# Processing chorale: bwv43.11.mxl
# Processing chorale: bwv430.mxl
# Processing chorale: bwv431.mxl
# Processing chorale: bwv432.mxl
# Processing chorale: bwv433.mxl
# Processing chorale: bwv434.mxl
# Processing chorale: bwv435.mxl
# Processing chorale: bwv436.mxl
# Processing chorale: bwv437.mxl
# Processing chorale: bwv438.mxl
# Processing chorale: bwv44.7.mxl
# Processing chorale: bwv45.7.mxl
# Processing chorale: bwv46.6.mxl
# Processing chorale: bwv47.5.mxl
# Processing chorale: bwv48.3.mxl
# Processing chorale: bwv48.7.mxl
# Processing chorale: bwv5.7.mxl
# Processing chorale: bwv52.6.mxl
# Processing chorale: bwv55.5.mxl
# Processing chorale: bwv56.5.mxl
# Processing chorale: bwv57.8.mxl
# Processing chorale: bwv59.3.mxl
# Processing chorale: bwv6.6.mxl
# Processing chorale: bwv60.5.mxl
# Processing chorale: bwv62.6.mxl
# Processing chorale: bwv64.2.mxl
# Processing chorale: bwv64.4.mxl
# Processing chorale: bwv64.8.mxl
# Processing chorale: bwv65.2.mxl
# Processing chorale: bwv65.7.mxl
# Processing chorale: bwv66.6.mxl
# Processing chorale: bwv67.4.xml
# Processing chorale: bwv67.7.mxl
# Processing chorale: bwv69.6-a.mxl
# Processing chorale: bwv69.6.xml
# Processing chorale: bwv7.7.mxl
# Processing chorale: bwv70.11.mxl
# Processing chorale: bwv70.7.mxl
# Processing chorale: bwv72.6.mxl
# Processing chorale: bwv73.5.mxl
# Processing chorale: bwv74.8.mxl
# Processing chorale: bwv77.6.mxl
# Processing chorale: bwv78.7.mxl
# Processing chorale: bwv79.3.mxl
# Processing chorale: bwv79.6.mxl
# Processing chorale: bwv8.6.mxl
# Processing chorale: bwv80.8.mxl
# Processing chorale: bwv81.7.mxl
# Processing chorale: bwv83.5.mxl
# Processing chorale: bwv84.5.mxl
# Processing chorale: bwv846.mxl
# Processing chorale: bwv85.6.mxl
# Processing chorale: bwv86.6.mxl
# Processing chorale: bwv87.7.mxl
# Processing chorale: bwv88.7.mxl
# Processing chorale: bwv89.6.mxl
# Processing chorale: bwv9.7.mxl
# Processing chorale: bwv90.5.mxl
# Processing chorale: bwv91.6.mxl
# Processing chorale: bwv92.9.mxl
# Processing chorale: bwv93.7.mxl
# Processing chorale: bwv94.8.mxl
# Processing chorale: bwv95.7.mxl
# Processing chorale: bwv96.6.mxl
# Processing chorale: bwv97.9.mxl
# Processing chorale: bwv99.6.mxl
# Processing chorale: Aus meines Herzens Grunde
# Processing chorale: Ich dank dir, lieber Herre
# Processing chorale: Ach Gott, vom Himmel sieh' darein
# Processing chorale: Es ist das Heil uns kommen her
# Processing chorale: An Wasserfluessen Babylon
# Processing chorale: Christus, der ist mein Leben
# Processing chorale: Nun lob, mein Seel, den Herren
# Processing chorale: Freuet euch, ihr Christen alle
# Processing chorale: Ermuntre dich, mein schwacher Geist
# Processing chorale: Aus tiefer Not schrei ich zu dir 1
# Processing chorale: Jesu, nun sei gepreiset
# Processing chorale: Puer natus in Bethlehem
# Processing chorale: Allein zu dir, Herr Jesu Christ
# Processing chorale: O Herre Gott, dein goettlich Wort
# Processing chorale: Christ lag in Todesbanden
# Processing chorale: Es woll uns Gott genaedig sein 2
# Processing chorale: Erschienen ist der herrliche Tag
# Processing chorale: Menschenkind, merk eben
# Processing chorale: Ich hab mein Sach Gott heimgestellt
# Processing chorale: Ein feste Burg ist unser Gott

# %%
#View durations frequencies of all chorales
durations_dict = Counter(all_durations)
durations_dict
# Out:
# Counter({1.0: 13675,
#          0.5: 4822,
#          0.25: 1471,
#          2.0: 1921,
#          1.5: 308,
#          4.0: 96,
#          3.0: 427,
#          0.75: 47,
#          8.0: 1,
#          6.0: 5,
#          0.125: 64,
#          0.0: 2})

# %%
plt.figure(figsize=(14,8))
plt.bar(range(len(durations_dict)), list(durations_dict.values()), align='center', color='blue')
plt.xticks(range(len(durations_dict)), list(durations_dict.keys()))
plt.xlabel("Quarter_length", fontsize=18)
plt.ylabel("Frequency", fontsize=18)
plt.title("Bach Chorale Note Length Distribution", fontsize=22)
plt.savefig('../figures/note_duration_distr.png', dpi=300)
plt.show()

# %%
#View pitch MIDI value frequencies of all chorale soprano parts
notes_dict = Counter(all_notes)
sorted(notes_dict)
# Out:
# [50,
#  53,
#  55,
#  57,
#  58,
#  59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  88]

# %%
plt.figure(figsize=(14,8))
plt.bar(range(len(notes_dict)), list(notes_dict.values()), align='center', color='blue')
plt.xticks(range(len(notes_dict)), list(notes_dict.keys()))
plt.xlabel("MIDI Pitch Value")
plt.ylabel("Frequency")
plt.title("Bach Chorale MIDI Pitch")

plt.show()

# %%
chorales_notes_train[0]
# Out:
# [(65, 1.0),
#  (67, 0.5),
#  (60, 0.5),
#  (65, 0.5),
#  (53, 0.5),
#  (57, 0.5),
#  (53, 0.5),
#  (57, 0.5),
#  (60, 0.5),
#  (65, 0.25),
#  (70, 0.25),
#  (69, 0.25),
#  (67, 0.25),
#  (65, 0.5),
#  (67, 0.5),
#  (69, 1.0),
#  (69, 1.0),
#  (65, 0.5),
#  (67, 0.25),
#  (69, 0.25),
#  (70, 0.5),
#  (72, 0.25),
#  (70, 0.25),
#  (69, 0.5),
#  (67, 0.5),
#  (67, 0.5),
#  (72, 0.5),
#  (72, 0.5),
#  (71, 0.25),
#  (69, 0.25),
#  (71, 1.0),
#  (72, 1.0),
#  (65, 1.0),
#  (65, 0.5),
#  (70, 0.5),
#  (69, 0.5),
#  (67, 0.5),
#  (65, 0.5),
#  (60, 0.5),
#  (65, 0.5),
#  (60, 0.5),
#  (60, 0.5),
#  (57, 0.25),
#  (53, 0.25),
#  (60, 0.5),
#  (60, 0.25),
#  (60, 0.25),
#  (57, 1.0),
#  (65, 1.0),
#  (67, 0.5),
#  (60, 0.5),
#  (65, 0.5),
#  (53, 0.5),
#  (57, 0.5),
#  (53, 0.5),
#  (57, 0.5),
#  (60, 0.5),
#  (65, 0.25),
#  (70, 0.25),
#  (69, 0.25),
#  (67, 0.25),
#  (65, 0.5),
#  (67, 0.5),
#  (69, 1.0),
#  (69, 1.0),
#  (65, 0.5),
#  (67, 0.25),
#  (69, 0.25),
#  (70, 0.5),
#  (72, 0.25),
#  (70, 0.25),
#  (69, 0.5),
#  (67, 0.5),
#  (67, 0.5),
#  (72, 0.5),
#  (72, 0.5),
#  (71, 0.25),
#  (69, 0.25),
#  (71, 1.0),
#  (72, 1.0),
#  (65, 1.0),
#  (65, 0.5),
#  (70, 0.5),
#  (69, 0.5),
#  (67, 0.5),
#  (65, 0.5),
#  (60, 0.5),
#  (65, 0.5),
#  (60, 0.5),
#  (60, 0.5),
#  (57, 0.25),
#  (53, 0.25),
#  (60, 0.5),
#  (60, 0.25),
#  (60, 0.25),
#  (57, 1.0),
#  (67, 0.5),
#  (60, 0.25),
#  (60, 0.25),
#  (60, 0.25),
#  (60, 0.25),
#  (60, 0.25),
#  (60, 0.25),
#  (65, 2.0),
#  (67, 0.25),
#  (65, 0.25),
#  (67, 0.25),
#  (69, 0.25),
#  (67, 1.0),
#  (65, 2.0),
#  (65, 0.5),
#  (60, 0.5),
#  (65, 0.5),
#  (60, 0.5),
#  (72, 0.5),
#  (70, 0.25),
#  (69, 0.25),
#  (70, 0.5),
#  (72, 0.25),
#  (70, 0.25),
#  (69, 0.5),
#  (67, 0.5),
#  (65, 0.5),
#  (60, 0.5),
#  (72, 1.5),
#  (60, 0.5),
#  (67, 0.5),
#  (65, 0.25),
#  (64, 0.25),
#  (65, 1.0),
#  (65, 0.5),
#  (53, 0.5),
#  (60, 0.5),
#  (60, 0.25),
#  (60, 0.25),
#  (57, 2.0),
#  (69, 0.25),
#  (67, 0.25),
#  (69, 0.25),
#  (70, 0.25),
#  (72, 1.0),
#  (72, 0.5),
#  (70, 1.0),
#  (69, 0.5),
#  (69, 0.5),
#  (67, 1.0),
#  (65, 0.5),
#  (65, 0.5),
#  (53, 0.5),
#  (60, 0.5),
#  (60, 0.25),
#  (60, 0.25),
#  (57, 1.0)]

# %%
print(f"Number of chorales analyzed: {len(chorales_notes_train)}")
# Out:
# Number of chorales analyzed: 433

# %%
#Visualize chords analyzed in corpus

chorales_chords_train[0]
# Out:
# ['I',
#  'V6',
#  'V6',
#  'I',
#  'I',
#  'vi',
#  'vi',
#  'I6',
#  'I6',
#  'IV',
#  'IV',
#  'IV7642',
#  'ii7542',
#  'IV6',
#  'vii/o7532',
#  'I',
#  'I',
#  'IV',
#  'ii65',
#  'IV7',
#  'viio752',
#  'V43',
#  'viio6',
#  'I6',
#  'II65',
#  'V',
#  'V',
#  'vi65',
#  '#iv/ob7b64b3',
#  'vi763',
#  'II',
#  'V',
#  'I',
#  'I',
#  'IV',
#  'ii65',
#  'iii6',
#  'iii65',
#  'IV65',
#  'V65',
#  'I',
#  'I',
#  'i54',
#  'I654',
#  'I654',
#  'V7',
#  'V7',
#  'V7',
#  'I',
#  'I',
#  'V6',
#  'V6',
#  'I',
#  'I',
#  'vi',
#  'vi',
#  'I6',
#  'I6',
#  'IV',
#  'IV',
#  'IV7642',
#  'ii7542',
#  'IV6',
#  'vii/o7532',
#  'I',
#  'I',
#  'IV',
#  'ii65',
#  'IV7',
#  'viio752',
#  'V43',
#  'viio6',
#  'I6',
#  'II65',
#  'V',
#  'V',
#  'vi65',
#  '#iv/ob7b64b3',
#  'vi763',
#  'II',
#  'V',
#  'I',
#  'I',
#  'IV',
#  'ii65',
#  'iii6',
#  'iii65',
#  'IV65',
#  'V65',
#  'I',
#  'I',
#  'i54',
#  'I654',
#  'I654',
#  'V7',
#  'V7',
#  'V7',
#  'I',
#  'V6',
#  'V6',
#  'V6',
#  'V6',
#  'V6',
#  'V6',
#  'V6',
#  'I',
#  'i54',
#  'i4',
#  'V',
#  'vi62',
#  'V',
#  'I',
#  'I',
#  'I742',
#  'I6',
#  'I',
#  'V',
#  'V7642',
#  'iii7542',
#  'V65',
#  'V',
#  'V7',
#  'I',
#  'I742',
#  'I6',
#  'I',
#  'V',
#  'I752',
#  'I6',
#  'ii',
#  'ii7',
#  'vii/o65',
#  'vi',
#  'vi6432',
#  'ii65',
#  'ii42',
#  'V',
#  'V',
#  'V',
#  'I',
#  'vi',
#  'vi543',
#  'vi6',
#  'IV43',
#  'iii',
#  'iii7',
#  'IV532',
#  'IV6',
#  'iv54',
#  'I',
#  'ii732',
#  'viio6',
#  'iii7',
#  'vi',
#  'II65',
#  'II65',
#  'V',
#  'V543',
#  'V',
#  'V',
#  'I']

# %%
#View chord counts over the entire corpus
chords_dict = Counter(all_chords)
chords_dict
# Out:
# Counter({'I': 3326,
#          'V6': 825,
#          'vi': 1027,
#          'I6': 1151,
#          'IV': 883,
#          'IV7642': 2,
#          'ii7542': 10,
#          'IV6': 559,
#          'vii/o7532': 11,
#          'ii65': 275,
#          'IV7': 164,
#          'viio752': 23,
#          'V43': 69,
#          'viio6': 302,
#          'II65': 171,
#          'V': 2669,
#          'vi65': 165,
#          '#iv/ob7b64b3': 2,
#          'vi763': 8,
#          'II': 371,
#          'iii6': 177,
#          'iii65': 71,
#          'IV65': 160,
#          'V65': 355,
#          'i54': 404,
#          'I654': 37,
#          'V7': 632,
#          'i4': 52,
#          'vi62': 6,
#          'I742': 94,
#          'V7642': 1,
#          'iii7542': 1,
#          'I752': 131,
#          'ii': 593,
#          'ii7': 291,
#          'vii/o65': 49,
#          'vi6432': 12,
#          'ii42': 126,
#          'vi543': 14,
#          'vi6': 230,
#          'IV43': 40,
#          'iii': 392,
#          'iii7': 150,
#          'IV532': 71,
#          'iv54': 191,
#          'ii732': 23,
#          'V543': 14,
#          'i': 1372,
#          'bVII6': 290,
#          'III': 1028,
#          'V#643': 26,
#          'bVI6': 195,
#          'bVII65': 78,
#          'III532': 52,
#          'iv65': 103,
#          'iv7': 179,
#          'bVII': 676,
#          'III6': 489,
#          'iv64': 66,
#          'iv6': 453,
#          'i64': 142,
#          'i752': 85,
#          'V75#3': 269,
#          'v42': 38,
#          'V64': 96,
#          'bVI43': 18,
#          'iio6': 191,
#          'III64': 83,
#          'iii54': 73,
#          'v2': 6,
#          'v': 345,
#          'bVI32': 1,
#          'i542': 8,
#          'iv43': 64,
#          'III32': 5,
#          'viio6#4': 9,
#          'i6': 399,
#          'iio64': 38,
#          'I6#42': 54,
#          'i43': 80,
#          'iv532': 66,
#          'bVI42': 54,
#          'iv752': 42,
#          'i742': 52,
#          'bVII632': 5,
#          'bVI': 468,
#          'iv': 688,
#          'v7': 186,
#          'bVII#753': 4,
#          'II74#3': 8,
#          'I65': 119,
#          'II65#3': 41,
#          'vi7#54': 3,
#          'II7#5#3': 30,
#          'vio#63': 80,
#          'bVI7': 102,
#          'iio752': 17,
#          'III+6#32': 1,
#          'ii754': 66,
#          'bvii6': 86,
#          'v/o43': 21,
#          'vo6': 70,
#          'I75#3': 79,
#          'bVI752': 27,
#          'bvi54': 40,
#          'III752': 36,
#          'bII': 97,
#          'bII#5#3##2': 1,
#          'vo64': 5,
#          'bvii75b3': 22,
#          'v6': 159,
#          'viio#63': 130,
#          'ii/o65': 178,
#          '#iii6b5': 2,
#          'bVII42': 85,
#          'IIIb753': 46,
#          'bII#7#5#3': 13,
#          'bvii': 95,
#          'bVI+6': 25,
#          'iv743': 29,
#          'bvi74': 12,
#          'ii#642': 1,
#          'v632': 18,
#          'ii6': 282,
#          'IV7#3': 17,
#          'i7': 101,
#          'bVII752': 16,
#          'bvii54': 44,
#          'i652': 4,
#          'i74': 62,
#          'ii542': 96,
#          'i532': 91,
#          'ii/o43': 99,
#          'III742': 51,
#          'iii4': 11,
#          'bVII7': 169,
#          'vi743': 53,
#          'I42': 237,
#          'vi42': 182,
#          'iv4': 38,
#          '#iob75b2': 7,
#          '#io6': 54,
#          'v43': 69,
#          'VI6#42': 10,
#          'VI': 133,
#          'bVII#7#3': 9,
#          'VI75#3': 61,
#          'IV+65#3': 3,
#          'vii/o7': 59,
#          '#io5b3': 15,
#          'ii64': 57,
#          'vii7': 48,
#          '#vo6': 33,
#          'ii72': 2,
#          'V42': 266,
#          'iv742': 54,
#          'vi/o#43': 3,
#          'viio#653': 22,
#          'viio': 81,
#          'IV6#42': 43,
#          'bVII64': 28,
#          'i65': 36,
#          'IV75#3': 55,
#          'bvii43': 14,
#          'III42': 81,
#          'viio7': 67,
#          'v4': 21,
#          'iv74': 48,
#          'ii/o7': 33,
#          'II75#3': 171,
#          'vi7': 222,
#          'v54': 65,
#          'II7#3': 63,
#          'I7': 98,
#          'I632': 19,
#          'iv62': 11,
#          'ii632': 26,
#          'vi64': 73,
#          'v52': 32,
#          'II#752': 4,
#          'IV64': 127,
#          'iii/o65b3': 26,
#          'iii/o7b5': 4,
#          'vii42': 3,
#          'VI74#2': 2,
#          'VI6': 51,
#          'IV+43': 4,
#          'ii32': 1,
#          'iii542': 13,
#          'vi72': 1,
#          'III75#3': 51,
#          'ii43': 79,
#          '#iv/o4b3': 4,
#          'V743': 17,
#          'iv762': 5,
#          'III43': 42,
#          'IV632': 12,
#          'III+#642': 5,
#          'viio532': 9,
#          'iv652': 6,
#          'i543': 8,
#          'IV#643': 20,
#          'V6#42': 67,
#          'v5#2': 15,
#          'III+65#3': 9,
#          'i42': 139,
#          'bVII742': 8,
#          '#ivo6': 155,
#          'v742': 14,
#          'bVII64#3': 4,
#          'III7': 66,
#          'V7542': 2,
#          'I43': 37,
#          'I64': 256,
#          'bVII#5#4#3': 2,
#          'VI65': 91,
#          'vii/o43': 88,
#          'vi7432': 1,
#          'V763': 11,
#          '#v/o7': 32,
#          'vi532': 62,
#          'III65': 85,
#          'I763': 35,
#          'viio742': 17,
#          'VI7#3': 6,
#          'viio64': 33,
#          'vii743': 4,
#          '#vo5b3': 15,
#          'bVII43': 22,
#          '#ivo': 7,
#          'IV74#2': 2,
#          'vi#2': 2,
#          'ii652': 28,
#          'iio': 28,
#          'IV5#32': 2,
#          'v5': 75,
#          'III763': 11,
#          'bVII743': 9,
#          'III432': 4,
#          'v65': 29,
#          'vi/o7': 40,
#          'i432': 5,
#          'i743': 18,
#          'i32': 7,
#          'viio#632': 5,
#          'v743': 22,
#          'iii64': 32,
#          'IV42': 74,
#          'V764': 5,
#          'VI#3': 1,
#          'v74': 22,
#          'vii': 44,
#          'I732': 6,
#          'V64#3': 7,
#          'ii742': 20,
#          'iv52': 78,
#          'V752': 40,
#          'vii/o62': 5,
#          'I532': 151,
#          'III#752': 3,
#          '#iiob7b53': 11,
#          'iii43': 78,
#          'vii/o42': 27,
#          'iii/o7b53': 13,
#          'bvii4#3': 5,
#          'II6#42': 71,
#          'vi754': 19,
#          'iii42': 60,
#          '#iv/o7': 39,
#          'VII6': 19,
#          'VII65#3': 22,
#          'IV742': 44,
#          '#vo4b3': 4,
#          'ii763': 5,
#          'II6': 150,
#          'V532': 59,
#          'II#643': 28,
#          'vii6': 41,
#          'ii432': 11,
#          'I432': 7,
#          'vii432': 4,
#          'vi432': 9,
#          'vi43': 51,
#          'viio632': 7,
#          'Ib753': 76,
#          'V6432': 12,
#          'IV543': 5,
#          '#iv/ob7b5b3b2': 1,
#          'vi542': 29,
#          '#iii/ob64b3': 6,
#          '#iiio4bb3': 6,
#          'bVII732': 4,
#          'i62': 11,
#          'bvii7': 11,
#          'vi2': 7,
#          'v62': 12,
#          'I7532': 9,
#          '#ivob64': 17,
#          'IV654': 10,
#          'iii/o7b532': 2,
#          'IV7653#3': 1,
#          'vi753#3': 1,
#          'IV6543': 39,
#          'ii752': 31,
#          'iii652': 13,
#          'I543': 48,
#          'v542': 18,
#          'iv42': 65,
#          '#iiio6': 54,
#          'bVI532': 27,
#          'III762': 4,
#          'bvi7': 2,
#          'bVI+65#3': 11,
#          'bviib643': 2,
#          'bII#3': 2,
#          'III64b3': 4,
#          'bvii74b3': 4,
#          'iv432': 1,
#          'bII#5#4#3': 4,
#          'III+64': 2,
#          'V#3': 8,
#          'vi4#2': 10,
#          'i763': 11,
#          '#ivob7b53': 51,
#          '#iii/o6b5b3': 4,
#          'ii/o42': 37,
#          '#ivo6b5b3': 9,
#          'II#3': 13,
#          'iii52': 34,
#          'iv763': 19,
#          'viio6#43': 19,
#          'iii74': 15,
#          'i52': 110,
#          '#ivo5b3': 21,
#          'vii7#53': 9,
#          'V742': 24,
#          'ii743': 123,
#          'i5': 57,
#          'iio632': 8,
#          'IV5#42': 1,
#          'v#54': 13,
#          'v64': 27,
#          'iio654': 1,
#          'III764': 2,
#          'iio54': 6,
#          'iii5': 15,
#          'I#752': 3,
#          'III654': 3,
#          'bVI64': 26,
#          'iv542': 8,
#          'bVII754': 1,
#          'iv732': 4,
#          'bvii52': 22,
#          'I#42': 3,
#          '#vob64b3': 9,
#          'II5#42': 1,
#          '#iv/ob6b42': 10,
#          'VI#643': 9,
#          '#iv': 3,
#          '#iio6': 4,
#          'VII7#3': 7,
#          'v7b32': 3,
#          'VI7#3b2': 1,
#          '#io7': 25,
#          '#ivo7': 11,
#          'viio763': 3,
#          'IV7532': 10,
#          'vi752': 49,
#          'vi7653': 1,
#          'vii65#3': 10,
#          '#ivb64b3': 1,
#          'iii743': 19,
#          'vii43': 12,
#          'II7653': 5,
#          'II763': 2,
#          'I6432': 8,
#          'ii7653': 11,
#          'ii532': 57,
#          'iii632': 9,
#          'vi742': 23,
#          'vii64': 13,
#          '#vob64': 3,
#          '#vob75b2': 2,
#          'V7432': 3,
#          'vii/o7653': 1,
#          'vi764': 9,
#          'vii/o7642': 3,
#          'vii652': 5,
#          'vi54': 38,
#          'v4#3': 6,
#          '#ivb7b3': 7,
#          'V542': 1,
#          'v/ob642': 21,
#          '#iiio7': 24,
#          'i632': 11,
#          'III732': 6,
#          'III+7#53': 5,
#          'viio64#2': 13,
#          'V#42': 7,
#          'vi/o6#43': 18,
#          'IV6#432': 1,
#          'bVI7532': 2,
#          'bVII7432': 1,
#          'bVII6432': 2,
#          'V743#2': 1,
#          'III7432': 2,
#          'i7643': 1,
#          'viio7#52': 12,
#          'iio763': 8,
#          'iio52': 2,
#          'IV+765#3': 1,
#          'vii75#2': 6,
#          'IV752': 37,
#          'IV7#32': 2,
#          'vio': 11,
#          'bII64': 1,
#          'viio#742': 5,
#          'viio52': 4,
#          'V632': 25,
#          'ii74': 12,
#          'bVI542': 7,
#          'bVII532': 14,
#          'ii#5': 1,
#          '#ivob642': 2,
#          '#ivo64': 5,
#          'vi54#2': 2,
#          'III+#532': 2,
#          'II765': 1,
#          '#ivob7b5': 2,
#          'I7#3': 25,
#          'iii763': 7,
#          'II5#32': 5,
#          'III6#42': 12,
#          'I+7#53': 7,
#          'IV63#2': 2,
#          'IV#75#3': 1,
#          'II652': 2,
#          'bVII763': 5,
#          'v6#54': 1,
#          'iii732': 13,
#          'iii752': 17,
#          'VI74#3': 3,
#          'vi4b32': 1,
#          'bVII#7#5#3': 7,
#          'i#753': 9,
#          'viio#43': 13,
#          'IV652': 1,
#          'V7#3': 42,
#          '#ivb42': 6,
#          '#iv6b5': 3,
#          'vi5': 14,
#          'I+43': 5,
#          'ii4': 11,
#          '#iv/ob64b3': 13,
#          'V#753': 9,
#          'I6b5': 48,
#          'V7532': 6,
#          'I32': 14,
#          'IV763': 21,
#          'I#643': 9,
#          '#iiio5b3': 8,
#          '#iiio6bb5b3': 16,
#          'bII#5#3#2': 8,
#          'vo75b2': 6,
#          'bvii7b3': 9,
#          'bviib3': 1,
#          'bvii74b2': 8,
#          'i/ob642': 1,
#          'viob753': 6,
#          'bvii62': 3,
#          'III6b5': 21,
#          '#iiiob6b42': 9,
#          'III#3': 8,
#          'iii532': 16,
#          'ii54': 36,
#          'vi732': 14,
#          'iii742': 8,
#          'II64': 11,
#          '#iv/o6b5b3': 7,
#          '#i/o7': 2,
#          'ii52': 26,
#          '#ivob76b3': 2,
#          'vi652': 8,
#          'vi632': 13,
#          'VII#643': 1,
#          'vi#764': 1,
#          'II#6#42': 10,
#          'bVI65': 18,
#          'bvi52': 21,
#          'V#763': 2,
#          'iii/ob642': 11,
#          'I63#2': 1,
#          'bIII': 6,
#          'vi/o43': 5,
#          'vb752': 11,
#          'viio74': 4,
#          'IV7#2': 2,
#          'IV#3': 5,
#          '#iiibb7b3': 6,
#          '#iiibb7b4b3': 1,
#          'iv632': 7,
#          'bVI732': 9,
#          'iv6543': 1,
#          'V54#3': 1,
#          'V5#32': 4,
#          'i6432': 2,
#          'bVI53#2': 1,
#          'v532': 8,
#          'v7532': 1,
#          'I5#3b2': 1,
#          'iv654': 3,
#          'iv764': 3,
#          'v732': 4,
#          'bVI75b43': 1,
#          'bVI654': 1,
#          'III743': 1,
#          'iio742': 1,
#          'bviib752': 6,
#          'bVI+43': 5,
#          'iv#753': 9,
#          'iv543': 3,
#          'IV75#32': 1,
#          'bVI+': 3,
#          'bVI+7#53': 7,
#          'iv6#53': 1,
#          'I6#432': 1,
#          'bVII543': 6,
#          'vio6#4': 11,
#          'ii65#3': 1,
#          'ii6#32': 3,
#          'v752': 11,
#          'bvii5': 4,
#          'V7#32': 2,
#          'V74#3': 12,
#          'IV432': 4,
#          '#iio': 2,
#          'iii53#2': 4,
#          '#ivo4b3': 4,
#          'vi/o64#2': 7,
#          '#vob62': 1,
#          'III7#3': 12,
#          'ii2': 31,
#          'ii5': 15,
#          'iiio6': 44,
#          'iii/o43': 14,
#          'iii754': 4,
#          'iiio': 13,
#          'I754': 2,
#          '#iv/ob7b5': 2,
#          'IV72': 4,
#          'I5432': 45,
#          'II632': 5,
#          'v5b42': 10,
#          '#ivb5b42': 4,
#          'IV542': 2,
#          'V762': 3,
#          'IV+6': 11,
#          '#iob64bb3': 9,
#          'IV+7#53': 3,
#          'vii/o6432': 1,
#          'IV7432': 1,
#          'I7432': 2,
#          'iii6432': 1,
#          'ii7632': 1,
#          'iii7653': 7,
#          'iii7532': 4,
#          '#iio64b3': 1,
#          'I765': 2,
#          'V7643': 2,
#          'I+6': 10,
#          'I+65#3': 4,
#          'ii6432': 8,
#          'Ib7532': 2,
#          'vii/o6543': 4,
#          'I6543': 7,
#          'iii6543': 2,
#          'vii542': 17,
#          'iv4#3': 8,
#          'bvii763': 4,
#          'vio532': 2,
#          'iii4b3': 1,
#          'bV': 9,
#          'bvii64': 15,
#          'io6': 6,
#          'bvii54b3': 1,
#          'io64': 1,
#          'vio6#2': 1,
#          'bII+6#5##3': 2,
#          'bvi4': 4,
#          'bII#7#3': 16,
#          'bII+##5#3#2': 1,
#          'bV6#42': 3,
#          'iiib75b3': 3,
#          'vii#762': 1,
#          'viio#74': 2,
#          'v652': 10,
#          'V76#2': 1,
#          'bVII+6': 9,
#          'vi6#43': 2,
#          'V5#3#2': 1,
#          '#iiiob5b3b2': 2,
#          '#ivb743': 1,
#          'III+6': 30,
#          'I#3': 13,
#          'bvii74': 11,
#          'v/o65b3': 45,
#          'i754': 9,
#          'vii732': 9,
#          'V654': 7,
#          'II7#32': 3,
#          'III+43': 6,
#          'III754': 1,
#          'ii#532': 6,
#          'I#64#3': 1,
#          'v6532': 2,
#          'bVI543': 6,
#          'III7532': 2,
#          'ii/o7542': 2,
#          'v432': 3,
#          'v6432': 2,
#          'iv754': 4,
#          'viio7543': 1,
#          'IV7653': 4,
#          'i#7#43': 1,
#          'vi/o#653': 21,
#          'III#764': 2,
#          'iv#764': 2,
#          'iv/o43': 1,
#          'bvi65': 1,
#          'bvi6': 2,
#          'vib7653': 1,
#          'Ib75432': 1,
#          'I64b3': 20,
#          'bVII#6#42': 11,
#          'V732': 4,
#          'VI75#3b2': 2,
#          'ii543': 6,
#          'V6543': 2,
#          'ii5432': 2,
#          'vb6543': 1,
#          '#vo6b5b3': 12,
#          'III#6543': 1,
#          '#vb5b42': 1,
#          'I764': 23,
#          'ib75': 14,
#          'IV764': 2,
#          'I+#532': 3,
#          'i+#62': 1,
#          'ii654': 5,
#          'I76b5': 1,
#          'vii764': 1,
#          'vi/ob642': 4,
#          'VI632': 3,
#          'vi52': 19,
#          'bV6': 3,
#          'bVI+7#42': 1,
#          'vii32': 3,
#          'vio7#52': 4,
#          'ii/o7653': 3,
#          'i654': 10,
#          'V#7542': 1,
#          'III5#43': 1,
#          'vi/o7#653': 1,
#          'iv63#2': 1,
#          'V74#2': 4,
#          'VI#65': 1,
#          'v72': 1,
#          'v#763': 1,
#          'bVI+64': 4,
#          '#iiiobb7b5': 1,
#          'vio75b2': 1,
#          'vio6': 4,
#          'IV32': 2,
#          'iii432': 5,
#          'bIII6': 8,
#          'IV6b5': 1,
#          'bVII#5#3#2': 4,
#          'i6b5': 3,
#          'bVII#4#32': 1,
#          'vb3': 10,
#          'v75b3': 13,
#          'ib75b3': 1,
#          'vb643': 1,
#          'IV64b3': 1,
#          'bIII64': 1,
#          'ib42': 1,
#          'i5b32': 1,
#          'bIII#42': 1,
#          'ib752': 1,
#          'bvii#54': 6,
#          'vi/ob62': 5,
#          'vi4': 18,
#          'bVI432': 2,
#          'i#73': 3,
#          'Ib73': 17,
#          'iiio64': 8,
#          '#iob76b3': 2,
#          'iii73#2': 2,
#          '#iiiob75b2': 3,
#          'bvii65': 27,
#          'iio532': 2,
#          'bVII762': 1,
#          'iio74': 1,
#          'i64#3': 4,
#          'bii#54': 3,
#          'bvi': 4,
#          '#ivob75b2': 4,
#          'v74b2': 3,
#          'IVb753': 2,
#          '#iob62': 1,
#          'bVIb753': 8,
#          'bVI742': 18,
#          'i764': 8,
#          'v764': 3,
#          'IV732': 1,
#          'viiob753': 1,
#          '#ivo7b4b2': 6,
#          'iii62': 3,
#          'bII#64#3': 4,
#          'iiob753': 1,
#          'bvii5b32': 7,
#          'vob7b53': 2,
#          'viob75': 1,
#          'i/o65b3': 12,
#          'bII6': 25,
#          'bII#6#42': 12,
#          'bvii6b42': 7,
#          'bV74#2': 1,
#          'bV#752': 1,
#          'bII7#5#3': 1,
#          '#vob6b42': 3,
#          'bVII#73': 4,
#          'ii#753': 3,
#          'III#643': 11,
#          'I762': 3,
#          'IV63b2': 2,
#          'V652': 1,
#          'I75432': 2,
#          'V754': 4,
#          'vi7532': 2,
#          'vi#7532': 2,
#          '#v7b2': 4,
#          '#vob5b3b2': 2,
#          'II#7542': 5,
#          'V#75432': 1,
#          'II#754': 2,
#          '#ivob5b3b2': 2,
#          'IV#8532': 1,
#          'v#75': 1,
#          'II74#2': 3,
#          'v/ob643': 1,
#          'IIIb73': 7,
#          'ii7#5': 3,
#          'ii#543': 1,
#          'viio7632': 2,
#          'ii7532': 4,
#          'III6#432': 2,
#          'V5432': 7,
#          'V75432': 2,
#          'iii7543': 2,
#          'II54#3': 2,
#          'vii765#3': 1,
#          'I#764': 2,
#          'vi5432': 2,
#          'ii6543': 2,
#          'ii#76543': 1,
#          'vii754#2': 1,
#          'V7632': 1,
#          'vb432': 1,
#          'v6b42': 3,
#          'bVII#64#3': 1,
#          'IVb7654': 1,
#          'IV76543': 1,
#          'II#42': 8,
#          'bVII+5#3': 1,
#          'IV+#532': 2,
#          'iv65#2': 3,
#          '#iiio7b4b2': 1,
#          'IV76#2': 2,
#          'V7652': 4,
#          'IV6432': 4,
#          'ii7642': 3,
#          'vb754': 3,
#          'iv2': 13,
#          'IV743': 4,
#          'viio654': 3,
#          '#iv2': 3,
#          'III5#32': 6,
#          'vi76#53': 2,
#          'vi654': 3,
#          'vii65': 3,
#          'I#7654': 1,
#          'II6532': 1,
#          'II7643#2': 1,
#          'vi76532': 1,
#          'III#7542': 1,
#          'vii754': 3,
#          'iii543': 2,
#          'V6542': 1,
#          '#ivb3b2': 2,
#          'II54#32': 1,
#          '#iiob5': 1,
#          'vii7#5': 1,
#          'iii543#2': 1,
#          '#i2': 1,
#          'VII#3': 2,
#          '#iob64': 1,
#          'v+#7#5': 1,
#          'III7#32': 1,
#          'ii3#3': 1,
#          'Ib732': 2,
#          'bVII#3': 1,
#          'V65432': 1,
#          'ii6532': 4,
#          'vi6532': 4,
#          'ii76432': 1,
#          'vi7643': 2,
#          'III#42': 2,
#          'iv5': 20,
#          'V432': 2,
#          'iiio6b32': 1,
#          'V7653': 3,
#          'vi74': 6,
#          'I7653': 1,
#          'vi7642': 3,
#          'bvi5#2': 2,
#          'v/o7b5': 9,
#          'bvii4': 6,
#          'iv32': 2,
#          'v32': 2,
#          'bVII542': 1,
#          '#ivob54': 1,
#          '#io6bb5b3': 8,
#          '#ivo6b3b2': 2,
#          'bVII#7#3##2': 1,
#          'v5b32': 4,
#          'VII': 5,
#          'iii#54': 1,
#          'v/o7b53': 12,
#          '#ivo64b3': 3,
#          '#iob7b53': 1,
#          '#ivo7b42': 2,
#          'IV#85#3': 1,
#          'III652': 1,
#          'V#732': 1,
#          'V32': 2,
#          'ii65#2': 1,
#          'i/o7b5': 2,
#          'vi73b2': 2,
#          'iiio75b2': 2,
#          'bVII6#3#2': 2,
#          'i4b3': 3,
#          'vi53b2': 3,
#          'IV765': 1,
#          'bIII#7#3': 1,
#          'IV+64': 3,
#          'v763': 2,
#          'v754': 6,
#          '#iiiob64bb3': 8,
#          'III#763': 1,
#          'v53#2': 7,
#          'vi#65': 2,
#          'vi7#65': 1,
#          'i4#3': 10,
#          'vio#742': 1,
#          'bVI+#532': 2,
#          'bvii#7': 1,
#          '#iobb7b5': 1,
#          'v#5b42': 1,
#          'i4b32': 1,
#          'vi/o65b3': 3,
#          'v7b3': 5,
#          'ib7b3': 1,
#          'i6#53': 1,
#          'vii#65': 2,
#          'viio6#2': 2,
#          'vo': 4,
#          'I5#42': 1,
#          'vii/o6#2': 1,
#          'bVI+#642': 3,
#          '#iiib7b3': 1,
#          'vii76#3': 1,
#          'iii764': 1,
#          '#ivb7b64': 1,
#          'I5#43': 4,
#          'I7652': 1,
#          '#iob54': 3,
#          'vii/o#753': 1,
#          'III+': 6,
#          'ii762': 2,
#          'IV+7#42': 1,
#          'bii#5#2': 3,
#          'I74#3': 8,
#          '#ib4b32': 2,
#          'VII65': 1,
#          'vi32': 2,
#          'iii762': 1,
#          'bVII32': 2,
#          'vi762': 1,
#          '#iiiob64': 6,
#          'bII#7#3#2': 1,
#          'II/o75#3': 1,
#          'vi6542': 1,
#          'I654b3': 1,
#          'i732': 6,
#          '#iii/o7': 3,
#          'III+654': 1,
#          'iii32': 2,
#          'IV#32': 1,
#          'IV53#2': 1,
#          'IV+76#3': 2,
#          'vio5#4': 3,
#          'IV74#3': 1,
#          'bii4#3': 1,
#          'bVI7b43': 1,
#          'bii#5##2': 1,
#          'bVI763': 4,
#          'bVII75#4': 1,
#          '#iii/ob7b5': 1,
#          'bII6#5#3': 1,
#          'bII7#4#2': 2,
#          'bVIIb863': 1,
#          '#vb7b3': 1,
#          '#iiob5b2': 2,
#          'iio6b5': 1,
#          'bVI73#2': 1,
#          'bVII432': 2,
#          '#io6b5b3': 1,
#          '#iiib74b3': 1,
#          'v3#2': 1,
#          '#ivob764': 1,
#          '#iob6b42': 2,
#          'ii7#53': 4,
#          'viio7#63': 1,
#          'bVII+64': 1,
#          'bVII#75#2': 1,
#          '#iio6b5b3': 1,
#          'bvi62': 2,
#          'bvii63#2': 1,
#          'iv72': 1,
#          'bvii#7b64': 1,
#          'bVI632': 1,
#          'bVII+64#3': 1,
#          'bVII+6#5#3': 1,
#          'bVII6#5#2': 1,
#          '#iv/ob62': 1,
#          'IV+#642': 4,
#          'V+64#3': 2,
#          '#i6bb5': 1,
#          'i762': 1,
#          'III632': 2,
#          'I74#2': 3,
#          'bVI65b2': 1,
#          'bVI+76#3': 2,
#          'bvii5b42': 3,
#          'bvi43': 4,
#          'IIIb743': 5,
#          'bVII#5#42': 1,
#          'IVb73': 1,
#          'ii64#3': 1,
#          'Ib743': 1,
#          '#ivb7b4b3': 1,
#          'III+75#2': 2,
#          'III72': 1,
#          'viio54': 1,
#          '#ib74b3': 1,
#          'IV64#4': 1,
#          'I6b52': 1,
#          '#iv7b2': 1,
#          'vib54': 1,
#          'IV+': 1,
#          'VI64': 2,
#          'V#73': 1,
#          '#vo6b3b2': 1,
#          'ii62': 9,
#          '#io4bb3': 5,
#          '#ivb75b3': 1,
#          '#ii/ob642': 1,
#          'IV76': 1,
#          'VI5#32': 1,
#          '#i6b42': 1,
#          'iii5#2': 3,
#          '#iii6': 4,
#          'bII#7#3##2': 1,
#          'I+#642': 2,
#          'iio5': 2,
#          'bII#75#2': 2,
#          '#vob76b3': 1,
#          'vi64#3': 1,
#          'bVII7#4#2': 2,
#          'ii765': 1,
#          'bvii#5#2': 2,
#          'iii#763': 1,
#          'ii4#3': 1,
#          'bvi5': 1,
#          'bV#42': 1,
#          'bV#3': 1,
#          'vio6#4b3': 1,
#          'bv#54': 1,
#          'bv5#2': 1,
#          ...})

# %%
print("Number of distinct chords in corpus: ", len(chords_dict.keys()))
# Out:
# Number of distinct chords in corpus:  1119

# %%
plt.figure(figsize=(16,8))
plt.bar(range(len(chords_dict)), list(chords_dict.values()), align='center', color='green')
plt.xticks(range(len(chords_dict)), list(chords_dict.keys()))
plt.xlabel("Chords")
plt.ylabel("Frequency")
plt.title("Bach Chorale Chords (Roman Numerals)")

plt.show()
